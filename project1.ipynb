# %% [markdown]
# <a href="https://colab.research.google.com/github/sushmitasasanur9-svg/Python-2026/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))
if num > 0:
 print("Positive")
elif num < 0:
 print("Negative")
else:
 print("Zero")
# Out:
# Enter a number: 3
# Positive

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
 print("Even")
else:
 print("Odd")
# Out:
# Enter a number: 4
# Even

# %%
age = int(input("Enter your age: "))
if age >= 18:
 print("Eligible to vote")
else:
 print("Not eligible to vote")
# Out:
# Enter your age: 17
# Not eligible to vote

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a > b:
 print("Largest is:", a)
else:
 print("Largest is:", b)
# Out:
# Enter first number: 4
# Enter second number: 6
# Largest is: 6

# %%
num = int(input("Enter a number: "))
if num % 5 == 0:
 print("Divisible by 5")
else:
 print("Not divisible by 5")
# Out:
# Enter a number: 10
# Divisible by 5

# %%
marks = int(input("Enter marks: "))
if marks >= 35:
 print("Pass")
else:
 print("Fail")
# Out:
# Enter marks: 56
# Pass

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == "+":
    print("Result:", a + b)

elif op == "-":
    print("Result:", a - b)

elif op == "*":
    print("Result:", a * b)

elif op == "/":
    if b != 0:
        print("Result:", a / b)
    else:
        print("Cannot divide by zero")

else:
    print("Invalid operator")
# Out:
# Enter first number: 2
# Enter second number: 4
# Enter operator (+, -, *, /): +
# Result: 6

# %%
year = int(input("Enter year: "))
if year % 4 == 0:
 print("Leap Year")
else:
 print("Not a Leap Year")
# Out:
# Enter year: 2005
# Not a Leap Year

# %%
temp = int(input("Enter temperature: "))
if temp > 35:
 print("Hot")
elif temp >= 20:
 print("Warm")
else:
 print("Cold")
# Out:
# Enter temperature: 29
# Warm

# %%
ch = input("Enter a character: ")
if ch in "aeiouAEIOU":
 print("Vowel")
else:
 print("Consonant")
# Out:
# Enter a character: sushmita
# Consonant

# %%
marks = int(input("Enter marks: "))
if marks >= 90:
 print("Grade A")
elif marks >= 75:
 print("Grade B")
elif marks >= 50:
 print("Grade C")
else:
 print("Fail")
# Out:
# Enter marks: 67
# Grade C

# %%
salary = float(input("Enter salary: "))
if salary > 50000:
 bonus = salary * 0.20
elif salary >= 30000:
 bonus = salary * 0.10
else:
 bonus = salary * 0.05
print("Total Salary:", salary + bonus)
# Out:
# Enter salary: 30000
# Total Salary: 33000.0

# %%
month = int(input("Enter month number (1-12): "))
if month in [1,3,5,7,8,10,12]:
 print("31 days")
elif month in [4,6,9,11]:
 print("30 days")
elif month == 2:
 print("28 or 29 days")
else:
 print("Invalid month")
# Out:
# Enter month number (1-12): 5
# 31 days

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a > b and a > c:
 print("Greatest is:", a)
elif b > c:
 print("Greatest is:", b)
else:
 print("Greatest is:", c)
# Out:
# Enter first number: 3
# Enter second number: 6
# Enter third number: 9
# Greatest is: 9

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin":
    if password == "1234":
        print("Login successful")
    else:
        print("Wrong password")
else:
    print("Username not found")
# Out:
# Enter username: sushmita
# Enter password: 12345
# Username not found

# %%
balance = 50000
withdraw = int(input("Enter withdrawal amount: "))

if balance >= withdraw:
    if withdraw <= 10000:
        print("Transaction successful")
    else:
        print("Limit exceeded")
else:
    print("Insufficient balance")
# Out:
# Enter withdrawal amount: 200
# Transaction successful

# %%
marks = int(input("Enter marks: "))
entrance = input("Did you pass entrance exam? (yes/no): ")

if marks >= 60:
    if entrance == "yes":
        print("Admission Granted")
    else:
        print("Entrance exam required")
else:
    print("Not eligible")
# Out:
# Enter marks: 45
# Did you pass entrance exam? (yes/no): yes
# Not eligible

# %%
units = int(input("Enter units consumed: "))

if units <= 100:
    bill = units * 5
else:
    if units <= 200:
        bill = (100 * 5) + ((units - 100) * 7)
    else:
        bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)

print("Total bill:", bill)
# Out:
# Enter units consumed: 78
# Total bill: 390

# %%
age = int(input("Enter age: "))

if age >= 18:
    if age >= 60:
        print("Senior Citizen")
    else:
        print("Adult")
else:
    if age >= 13:
        print("Teenager")
    else:
        print("Child")
# Out:
# Enter age: 67
# Senior Citizen

# %%
salary = int(input("Enter salary: "))
cibil = int(input("Enter CIBIL score: "))

if salary >= 25000:
    if cibil >= 700:
        print("Loan Approved")
    else:
        print("Low CIBIL score")
else:
    print("Salary too low")
# Out:
# Enter salary: 5000
# Enter CIBIL score: 6000
# Salary too low

# %%
m1 = int(input("Enter marks of subject 1: "))
m2 = int(input("Enter marks of subject 2: "))
m3 = int(input("Enter marks of subject 3: "))
m4 = int(input("Enter marks of subject 4: "))
m5 = int(input("Enter marks of subject 5: "))

if m1 < 35 or m2 < 35 or m3 < 35 or m4 < 35 or m5 < 35:
    print("Fail")
else:
    average = (m1 + m2 + m3 + m4 + m5) / 5
    print("Average:", average)

    if average >= 90:
        print("Grade A")
    elif average >= 75:
        print("Grade B")
    elif average >= 50:
        print("Grade C")
    else:
        print("Pass")
# Out:
# Enter marks of subject 1: 45
# Enter marks of subject 2: 89
# Enter marks of subject 3: 76
# Enter marks of subject 4: 56
# Enter marks of subject 5: 43
# Average: 61.8
# Grade C
